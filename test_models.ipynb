# %%
import pandas as pd
from sklearn.datasets import make_blobs, make_classification, make_moons, make_regression
import numpy as np
from LinearRegression import Lin_Reg,Lin_Reg_GD
from Logistic_regression import Logistic_Regression, Logistic_Regression_momentum
from Perceptron import Perceptron
from Knn import KNN
% matplotlib inline
% run __init__.py
from sklearn.cross_validation import train_test_split
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# Non tech presentation 2 sentences on everything im doing and why I chose to use it
# Diagrams of how these algorithms work

# %% [markdown]
# # Linear Regression

# %%
X, y = make_regression(n_samples = 500, n_features = 3)
X_test, X_train, y_test, y_train = train_test_split(X,y)
X.shape
# Out:
# (500, 3)

# %%
lr = Lin_Reg()
lr.fit(X_train,y_train)

# %%
lr.predict(X_test)
# Out:
# array([-156.36612611,  -81.9892542 ,   -0.58880608,  -21.69592293,
#           3.50346429,  -13.96273944,   61.10828246,   85.92948785,
#        -101.0587146 ,  177.32940032,   25.34944087,  107.31594009,
#         117.64063004,  105.46356974,  -42.73244498,  -53.12710675,
#          86.80924017,  253.95540933,  210.81224703,  128.34383366,
#          -7.68405658,  -34.41691502,  102.31328859,  -65.26597313,
#        -184.96454333,  -27.63127869,   56.16232768,   35.18268537,
#        -279.42854481,  102.49170337,   83.57149652,   65.09035591,
#        -188.68691503,  -50.34031735,  -91.11637591,  222.70780854,
#          79.72829113,  -37.64218651,   66.7351653 ,   27.52418072,
#          79.45277097, -178.5898776 , -129.33999652,  215.47116452,
#          95.00419803,   60.1751477 ,   13.91718222,   62.52330575,
#        -183.26072318,   28.6177179 , -110.40118321,   60.19354528,
#        -147.39864344,   28.39313239, -302.54613265,  150.01578292,
# ...

# %% [markdown]
# ### with gradient descent

# %%
X, y = make_regression(n_samples = 500, n_features = 5, bias = 43, noise = 0)
X_test, X_train, y_test, y_train = train_test_split(X,y)

# %%
lrg = Lin_Reg_GD()

# %% [raw]
# lrg.fit(X_train,y_train)

# %%
lrg.predict(X_test,y_test)

# %% [markdown]
# # Logistic Regression

# %%
X,y = make_classification(n_samples = 500 , n_features = 20)
X_test, X_train, y_test, y_train = train_test_split(X,y)

# %%
LG = Logistic_Regression(lr = .1, n_iterations = 5000)
LG.fit(X_train, y_train)
X_train.shape
# Out:
# 4.83885933789
# 4.83885933789
# 4.68284500326
# 4.68284500326
# 4.52750860083
# 4.52750860083
# 4.37299495539
# 4.37299495539
# 4.21949127929
# 4.21949127929
# 4.06723669356
# 4.06723669356
# 3.91653234578
# 3.91653234578
# 3.76775051305
# 3.76775051305
# 3.62133980098
# 3.62133980098
# 3.47782220471
# 3.47782220471
# 3.33777728847
# 3.33777728847
# 3.20181049188
# 3.20181049188
# 3.07050751362
# 3.07050751362
# 2.94438345142
# 2.94438345142
# 2.82383965894
# 2.82383965894
# 2.70913923166
# 2.70913923166
# 2.60040449425
# 2.60040449425
# 2.4976320198
# 2.4976320198
# 2.40071698446
# 2.40071698446
# 2.30947939823
# 2.30947939823
# 2.22368762854
# 2.22368762854
# 2.14307742509
# 2.14307742509
# 2.0673664113
# 2.0673664113
# 1.99626476486
# 1.99626476486
# 1.92948295028
# 1.92948295028
# 1.86673724209
# 1.86673724209
# 1.80775359474
# 1.80775359474
# 1.75227025898
# 1.75227025898
# 1.70003943532
# 1.70003943532
# 1.6508281838
# 1.6508281838
# 1.60441876403
# 1.60441876403
# ...

# %%
X,y = make_classification(n_samples = 20)
X_test, X_train, y_test, y_train = train_test_split(X,y)

# %%
LG = Logistic_Regression_momentum(lr = .1)
LG.fit(X_train, y_train)
# Out:
# 1.61264125647
# 1.61264125647
# 1.22166995409
# 0.904617048339
# 0.688945400996
# 0.544383025365
# 0.444262113703
# 0.37209173236
# 0.318195898589
# 0.276743977222
# 0.244070572918
# 0.217777638817
# 0.196241514436
# 0.178330202781
# 0.163234295882
# 0.15036211842
# 0.139272631633
# 0.129631315754
# 0.121180457373
# 0.113718705507
# 0.107086731387
# 0.10115699238
# 0.0958263082013
# 0.0910103976972
# 0.0866398042398
# 0.0826568190433
# 0.0790131313487
# 0.0756680146843
# 0.0725869130907
# 0.069740328991
# 0.0671029408543
# 0.0646528975678
# 0.0623712498981
# 0.0602414891872
# 0.058249170584
# 0.0563816034054
# 0.0546275951749
# 0.0529772388614
# 0.0514217351015
# 0.0499532429167
# 0.048564753768
# 0.0472499848276
# 0.0460032881495
# 0.0448195730608
# 0.0436942395922
# 0.042623121171
# 0.0416024351118
# 0.0406287397038
# 0.039698896895
# 0.0388100397446
# 0.0379595439508
# 0.0371450028743
# 0.0363642055679
# 0.0356151174015
# 0.0348958629324
# 0.0342047107253
# 0.0335400598678
# ...

# %%
pd.DataFrame(LG.predict(X_test)*100)
# Out:
#             0          1          2          3          4
# 0    0.004846  34.110021  20.958127  22.358198  22.568809
# 1   53.286389  18.917300   9.480099   8.963426   9.352786
# 2   99.841787   0.004688   0.050890   0.052581   0.050053
# 3   92.004563   0.316817   2.701386   2.576092   2.401142
# 4   99.331448   0.010035   0.220364   0.227016   0.211138
# 5    4.970647  13.384728  26.426282  27.333160  27.885184
# 6    9.951492  57.607241  11.145477  10.901852  10.393939
# 7    0.054942  98.409034   0.505103   0.569279   0.461642
# 8   40.987026  18.919638  13.763529  13.084065  13.245741
# 9    0.031023  98.460987   0.437273   0.539373   0.531344
# 10   2.829160  68.448171   9.806004   9.140432   9.776233
# 11   3.645128  60.800744  12.009828  11.910528  11.633771
# 12   0.562535  51.169599  15.919657  15.785700  16.562509
# 13  92.056476   0.010668   2.632588   2.637595   2.662673
# 14  81.506150   1.408771   5.627457   6.155388   5.302233

# %% [markdown]
# # Perceptron

# %%
pr = Perceptron(20,10,2)

# %%
pr.forward(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ba0b85e82fc1> in <module>()
# ----> 1 pr.forward(X)
#
# AttributeError: 'Perceptron' object has no attribute 'forward'

# %% [markdown]
# # KNN

# %%
X,y = make_blobs(centers = 3, cluster_std = 1.0, random_state = 42)

fig = plt.figure(figsize=(12,5))
plt.scatter(X[:, 0], X[:, 1])

# %%
X
# Out:
# array([[ -7.72642091,  -8.39495682],
#        [  5.45339605,   0.74230537],
#        [ -2.97867201,   9.55684617],
#        [  6.04267315,   0.57131862],
#        [ -6.52183983,  -6.31932507],
#        [  3.64934251,   1.40687195],
#        [ -2.17793419,   9.98983126],
#        [  4.42020695,   2.33028226],
#        [  4.73695639,   2.94181467],
#        [ -3.6601912 ,   9.38998415],
#        [ -3.05358035,   9.12520872],
#        [ -6.65216726,  -5.57296684],
#        [ -6.35768563,  -6.58312492],
#        [ -3.6155326 ,   7.8180795 ],
#        [ -1.77073104,   9.18565441],
#        [ -7.95051969,  -6.39763718],
#        [ -6.60293639,  -6.05292634],
#        [ -2.58120774,  10.01781903],
#        [ -7.76348463,  -6.72638449],
#        [ -6.40638957,  -6.95293851],
#        [ -2.97261532,   8.54855637],
#        [ -6.9567289 ,  -6.53895762],
#        [ -7.32614214,  -6.0237108 ],
#        [ -2.14780202,  10.55232269],
#        [ -2.54502366,  10.57892978],
# ...

# %%
X_test, X_train, y_test, y_train = train_test_split(X,y)

# %%
class KNN(object):
    
    def __init__(self, k = 3):
        self.k = k
        pass

    def train(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self,X):
        distances = []
        targets = []
        
        for i in range(len(X_train)):
            dist = self.distance(X,i)
            distances.append(dist)
        return distances

    def distance(self, X_test,i):
        sums_square = np.sum(np.square(X_test - self.X_train[i]))
        distances = np.sqrt(sums_square)
                
        return distances

# %%
l = KNN()
l.train(X_train,y_train)

# %%
l.predict(X_test)
# Out:
# [87.158934048841033,
#  87.05721978861817,
#  100.70195383181554,
#  99.815723117279234,
#  115.52012016293158,
#  115.92050418093132,
#  90.051307453673587,
#  99.761607633895508,
#  87.611086847322241,
#  112.91836944223115,
#  97.237888513530464,
#  93.834875699124282,
#  102.29135531094792,
#  101.63991083358881,
#  86.414944878803453,
#  107.22895461559696,
#  85.34323706732053,
#  85.363833003408288,
#  95.445222034669754,
#  95.008055608043733,
#  111.64816678205668,
#  105.01903586699351,
#  91.70142801928813,
#  108.28275151137174,
#  105.43277246425983]

# %% [markdown]
# ### Ignore

# %%
N = 100 # number of points per class
D = 2 # dimensionality
K = 3 # number of classes
X = np.zeros((N*K,D)) # data matrix (each row = single example)
y = np.zeros(N*K, dtype='uint8') # class labels
for j in range(K):
    ix = range(N*j,N*(j+1))
    r = np.linspace(0.0,1,N) # radius
    t = np.linspace(j*4,(j+1)*4,N) + np.random.randn(N)*0.2 # theta
    X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
    y[ix] = j
# lets visualize the data:
plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
plt.show()

# %%
# initialize parameters randomly
W = 0.01 * np.random.randn(D,K)
b = np.zeros((1,K))

# some hyperparameters
step_size = 1e-0
reg = 1e-3 # regularization strength

# gradient descent loop
num_examples = X.shape[0]
for i in range(200):
  
  # evaluate class scores, [N x K]
    scores = np.dot(X, W) + b 
  
  # compute the class probabilities
    exp_scores = np.exp(scores)
    probs = exp_scores / np.sum(exp_scores, axis=1, keepdims=True) # [N x K]
    print(probs)
  
  # compute the loss: average cross-entropy loss and regularization
    corect_logprobs = -np.log(probs[range(num_examples),y])
    data_loss = np.sum(corect_logprobs)/num_examples
    
    #print(corect_logprobs)
    loss = data_loss

    if i % 10 == 0:
        pass
        #print ("iteration %d: loss %f" % (i, loss))
        #print(sum(scores))
  
  # compute the gradient on scores
    dscores = probs
    dscores[range(num_examples),y] -= 1
    dscores /= num_examples
  
  # backpropate the gradient to the parameters (W,b)
    dW = np.dot(X.T, dscores)
    db = np.sum(dscores, axis=0, keepdims=True)
  
    dW += reg*W # regularization gradient
  
  # perform a parameter update
    W += -step_size * dW
    b += -step_size * db

# %%
print(X.shape[0])

# %%
data_loss.shape

# %%
def softmax(vec):
    return np.exp(vec) / np.sum(np.exp(vec))

logits = np.random.randint(0, 5, size = (100, 3))

probs = np.apply_along_axis(softmax, 1, logits)
y = np.random.randint(0, 3, size = 100)

# %%
probs

# %%
probs[range(100),y]

# %%
y

# %%
X.shape
